# %% [markdown]
# <a href="https://colab.research.google.com/github/meti-94/TextGeneration/blob/main/generate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "ray[tune]" transformers datasets==1.1.2
# !pip install transformers
# !ray install-nightly
# !pip install rouge_score
# !pip install -U ray
# !pip install -U transformers datasets
# !pip install tensorboardX
# Out:
# Collecting ray[tune]
#   Downloading https://files.pythonhosted.org/packages/0b/d0/33b6f8789cec27ac07e33de987eef9430b211c7d8284437371e45d37bbd5/ray-1.3.0-cp37-cp37m-manylinux2014_x86_64.whl (49.7MB)
#      |████████████████████████████████| 49.7MB 59kB/s
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 49.7MB/s
# Collecting datasets==1.1.2
#   Downloading https://files.pythonhosted.org/packages/f0/f4/2a3d6aee93ae7fce6c936dda2d7f534ad5f044a21238f85e28f0b205adf0/datasets-1.1.2-py3-none-any.whl (147kB)
#      |████████████████████████████████| 153kB 58.5MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (2.23.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.19.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.0.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (3.13)
# Collecting redis>=3.5.0
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 10.4MB/s
# Collecting protobuf>=3.15.3
#   Downloading https://files.pythonhosted.org/packages/cd/4d/b5088b78457f4b4b729313fa4a6c67481fe3d2c4cd0a2e5bb7c873b6bb25/protobuf-3.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 50.1MB/s
# Collecting opencensus
#   Downloading https://files.pythonhosted.org/packages/e2/d6/b952f11b29c3a0cbec5620de3c4260cecd8c4329d83e91587edb48691e15/opencensus-0.7.12-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 58.2MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (0.10.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.0.2)
# Collecting py-spy>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/bc/5f/586c5399b30e5589ff1f6e09eaf96ae810fe4071340677cbaed9a5fc2947/py_spy-0.3.6-py2.py3-none-manylinux1_x86_64.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 49.5MB/s
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.32.0)
# Collecting gpustat
#   Downloading https://files.pythonhosted.org/packages/b4/69/d8c849715171aeabd61af7da080fdc60948b5a396d2422f1f4672e43d008/gpustat-0.6.0.tar.gz (78kB)
#      |████████████████████████████████| 81kB 8.0MB/s
# Collecting aiohttp-cors
#   Downloading https://files.pythonhosted.org/packages/13/e7/e436a0c0eb5127d8b491a9b83ecd2391c6ff7dcd5548dfaec2080a2340fd/aiohttp_cors-0.7.0-py3-none-any.whl
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/88/c0/5890b4c8b04a79b7360e8fe4490feb0bb3ab179743f199f0e6220cebd568/aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 44.6MB/s
# Collecting aioredis
#   Downloading https://files.pythonhosted.org/packages/b0/64/1b1612d0a104f21f80eb4c6e1b6075f2e6aba8e228f46f229cfd3fdac859/aioredis-1.3.1-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 10.6MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (2.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (7.1.2)
# Requirement already satisfied: pandas; extra == "tune" in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (1.1.5)
# Collecting tensorboardX; extra == "tune"
#   Downloading https://files.pythonhosted.org/packages/07/84/46421bd3e0e89a92682b1a38b40efc22dafb6d8e3d947e4ceefd4a5fabc7/tensorboardX-2.2-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 62.3MB/s
# Requirement already satisfied: tabulate; extra == "tune" in /usr/local/lib/python3.7/dist-packages (from ray[tune]) (0.8.9)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 47.2MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 45.5MB/s
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.1.2) (3.0.0)
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 55.8MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.1.2) (0.3.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.1.2) (0.70.11.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]) (3.0.4)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.15.3->ray[tune]) (1.15.0)
# Requirement already satisfied: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[tune]) (1.26.3)
# Collecting opencensus-context==0.1.2
#   Downloading https://files.pythonhosted.org/packages/f1/33/990f1bd9e7ee770fc8d3c154fc24743a96f16a0e49e14e1b7540cc2fdd93/opencensus_context-0.1.2-py2.py3-none-any.whl
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[tune]) (7.352.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[tune]) (5.4.8)
# Collecting blessings>=1.6
#   Downloading https://files.pythonhosted.org/packages/03/74/489f85a78247609c6b4f13733cbf3ba0d864b11aa565617b645d6fdf2a4a/blessings-1.7-py3-none-any.whl
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/7c/a6/4123b8165acbe773d1a8dc8e3f0d1edea16d29f7de018eda769abb56bd30/multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142kB)
#      |████████████████████████████████| 143kB 55.8MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/f1/62/046834c5fc998c88ab2ef722f5d42122230a632212c8afa76418324f53ff/yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294kB)
#      |████████████████████████████████| 296kB 44.6MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[tune]) (20.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[tune]) (3.7.4.3)
# Collecting hiredis
#   Downloading https://files.pythonhosted.org/packages/ed/33/290cea35b09c80b4634773ad5572a8030a87b5d39736719f698f521d2a13/hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85kB)
#      |████████████████████████████████| 92kB 13.2MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas; extra == "tune"->ray[tune]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas; extra == "tune"->ray[tune]) (2.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (1.53.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (56.1.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (1.28.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (4.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[tune]) (0.4.8)
# Building wheels for collected packages: gpustat
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-cp37-none-any.whl size=12621 sha256=d68bed4b7e121a99c71a083ac8a634e625709ea14f96fbd96064d3ce9e2e84f4
#   Stored in directory: /root/.cache/pip/wheels/48/b4/d5/fb5b7f1d040f2ff20687e3bad6867d63155dbde5a7c10f4293
# Successfully built gpustat
# Installing collected packages: colorama, redis, protobuf, opencensus-context, opencensus, py-spy, blessings, gpustat, async-timeout, multidict, yarl, aiohttp, aiohttp-cors, hiredis, aioredis, tensorboardX, ray, tokenizers, sacremoses, transformers, xxhash, datasets
#   Found existing installation: protobuf 3.12.4
#     Uninstalling protobuf-3.12.4:
#       Successfully uninstalled protobuf-3.12.4
# Successfully installed aiohttp-3.7.4.post0 aiohttp-cors-0.7.0 aioredis-1.3.1 async-timeout-3.0.1 blessings-1.7 colorama-0.4.4 datasets-1.1.2 gpustat-0.6.0 hiredis-2.0.0 multidict-5.1.0 opencensus-0.7.12 opencensus-context-0.1.2 protobuf-3.16.0 py-spy-0.3.6 ray-1.3.0 redis-3.5.3 sacremoses-0.0.45 tensorboardX-2.2 tokenizers-0.10.2 transformers-4.5.1 xxhash-2.0.2 yarl-1.6.3
# /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)
# Running: /usr/bin/python3 -m pip install -U https://s3-us-west-2.amazonaws.com/ray-wheels/latest/ray-2.0.0.dev0-cp37-cp37m-manylinux2014_x86_64.whl.
# Collecting ray==2.0.0.dev0
#   Downloading https://s3-us-west-2.amazonaws.com/ray-wheels/latest/ray-2.0.0.dev0-cp37-cp37m-manylinux2014_x86_64.whl (49.5MB)
#      |████████████████████████████████| 49.5MB 69kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (1.19.5)
# Requirement already satisfied, skipping upgrade: py-spy>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (0.3.6)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (2.6.0)
# Requirement already satisfied, skipping upgrade: aiohttp in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (3.7.4.post0)
# Requirement already satisfied, skipping upgrade: colorama in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (0.4.4)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (3.13)
# Requirement already satisfied, skipping upgrade: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (1.32.0)
# Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (7.1.2)
# Requirement already satisfied, skipping upgrade: gpustat in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (0.6.0)
# Requirement already satisfied, skipping upgrade: aiohttp-cors in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (0.7.0)
# Requirement already satisfied, skipping upgrade: redis>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (3.5.3)
# Requirement already satisfied, skipping upgrade: opencensus in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (0.7.12)
# Requirement already satisfied, skipping upgrade: aioredis in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (1.3.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (2.23.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (3.16.0)
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (1.0.2)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (3.0.12)
# Requirement already satisfied, skipping upgrade: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray==2.0.0.dev0) (0.10.1)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==2.0.0.dev0) (1.6.3)
# Requirement already satisfied, skipping upgrade: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==2.0.0.dev0) (3.0.4)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==2.0.0.dev0) (3.0.1)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==2.0.0.dev0) (5.1.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==2.0.0.dev0) (20.3.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray==2.0.0.dev0) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.28.1->ray==2.0.0.dev0) (1.15.0)
# Requirement already satisfied, skipping upgrade: blessings>=1.6 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray==2.0.0.dev0) (1.7)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray==2.0.0.dev0) (7.352.0)
# Requirement already satisfied, skipping upgrade: psutil in /usr/local/lib/python3.7/dist-packages (from gpustat->ray==2.0.0.dev0) (5.4.8)
# Requirement already satisfied, skipping upgrade: opencensus-context==0.1.2 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray==2.0.0.dev0) (0.1.2)
# Requirement already satisfied, skipping upgrade: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray==2.0.0.dev0) (1.26.3)
# Requirement already satisfied, skipping upgrade: hiredis in /usr/local/lib/python3.7/dist-packages (from aioredis->ray==2.0.0.dev0) (2.0.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray==2.0.0.dev0) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray==2.0.0.dev0) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray==2.0.0.dev0) (2020.12.5)
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (1.28.1)
# Requirement already satisfied, skipping upgrade: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (20.9)
# Requirement already satisfied, skipping upgrade: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (2018.9)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (56.1.0)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (1.53.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (4.7.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (4.2.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (2.4.7)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray==2.0.0.dev0) (0.4.8)
# Installing collected packages: ray
#   Found existing installation: ray 1.3.0
#     Uninstalling ray-1.3.0:
#       Successfully uninstalled ray-1.3.0
# Successfully installed ray-2.0.0.dev0
# Collecting rouge_score
#   Downloading https://files.pythonhosted.org/packages/1f/56/a81022436c08b9405a5247b71635394d44fe7e1dbedc4b28c740e09c2840/rouge_score-0.0.4-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge_score) (3.2.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score) (0.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.19.5)
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.0.4
# Requirement already up-to-date: ray in /usr/local/lib/python3.7/dist-packages (2.0.0.dev0)
# Requirement already satisfied, skipping upgrade: gpustat in /usr/local/lib/python3.7/dist-packages (from ray) (0.6.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray) (3.13)
# Requirement already satisfied, skipping upgrade: aiohttp in /usr/local/lib/python3.7/dist-packages (from ray) (3.7.4.post0)
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray) (1.0.2)
# Requirement already satisfied, skipping upgrade: py-spy>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ray) (0.3.6)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray) (2.6.0)
# Requirement already satisfied, skipping upgrade: opencensus in /usr/local/lib/python3.7/dist-packages (from ray) (0.7.12)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from ray) (2.23.0)
# Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray) (7.1.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray) (1.19.5)
# Requirement already satisfied, skipping upgrade: redis>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ray) (3.5.3)
# Requirement already satisfied, skipping upgrade: aioredis in /usr/local/lib/python3.7/dist-packages (from ray) (1.3.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray) (3.16.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray) (1.32.0)
# Requirement already satisfied, skipping upgrade: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray) (0.10.1)
# Requirement already satisfied, skipping upgrade: aiohttp-cors in /usr/local/lib/python3.7/dist-packages (from ray) (0.7.0)
# Requirement already satisfied, skipping upgrade: colorama in /usr/local/lib/python3.7/dist-packages (from ray) (0.4.4)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from ray) (3.0.12)
# Requirement already satisfied, skipping upgrade: blessings>=1.6 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (1.7)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (7.352.0)
# Requirement already satisfied, skipping upgrade: psutil in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (5.4.8)
# Requirement already satisfied, skipping upgrade: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray) (1.15.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (20.3.0)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (3.0.1)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (5.1.0)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (1.6.3)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray) (3.0.4)
# Requirement already satisfied, skipping upgrade: opencensus-context==0.1.2 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray) (0.1.2)
# Requirement already satisfied, skipping upgrade: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray) (1.26.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2020.12.5)
# Requirement already satisfied, skipping upgrade: hiredis in /usr/local/lib/python3.7/dist-packages (from aioredis->ray) (2.0.0)
# Requirement already satisfied, skipping upgrade: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (20.9)
# Requirement already satisfied, skipping upgrade: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (2018.9)
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.28.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (56.1.0)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.53.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (2.4.7)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.2.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.7.2)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.4.8)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.7/dist-packages (2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.19.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.16.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)

# %%
# !wget https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json
# !mkdir models
# Out:
# --2021-05-08 16:18:31--  https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.108.62
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.108.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209850483 (200M) [application/json]
# Saving to: ‘personachat_self_original.json’
#
# personachat_self_or 100%[===================>] 200.13M  42.5MB/s    in 5.2s
#
# 2021-05-08 16:18:37 (38.1 MB/s) - ‘personachat_self_original.json’ saved [209850483/209850483]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import ray
# from ray.tune.suggest.hyperopt import HyperOptSearch
# from ray.tune.schedulers import AsyncHyperBandScheduler



from transformers import EncoderDecoderModel, BertTokenizer, BertModel, BertConfig
from typing import Any, Dict, List, Optional, Tuple, Union
import torch
from torch.utils.data import Dataset
from transformers import AdamW
from tqdm import tqdm
import json
import random 
from sklearn.model_selection import train_test_split
from datetime import datetime
from transformers import Seq2SeqTrainer
from transformers import Seq2SeqTrainingArguments
from tqdm import tqdm_notebook as tqdm
import logging
import datasets
logging.basicConfig(level=logging.DEBUG)


global print_threshold, counter
print_threshold = 10
counter = 0
# from customize.trainer_customization import CustomSeq2SeqTrainer

# %%
SPECIAL_TOKENS = ["<bos>", "<eos>", "<persona>", "<speaker1>", "<speaker2>", "<pad>"]

ATTR_TO_SPECIAL_TOKEN = {'bos_token': '<bos>', 'eos_token': '<eos>', 'pad_token': '<pad>',
                         'additional_special_tokens': ['<speaker1>', '<speaker2>', '<persona>']}

encoder_max_length=512
decoder_max_length=128

def read_data(data_json_path='/content/personachat_self_original.json'):
  with open(data_json_path) as json_file:
    data_dict = json.load(json_file)
  return data_dict

def data_to_samples(data_dict, test=False):
  samples=[]
  for dialogue in (data_dict['train'] if test==False else data_dict['valid']):
    original_persona = dialogue['personality']
    
    for item in dialogue['utterances']:
      original_persona = [original_persona[-1]] + original_persona[:-1]
      history = item['history']
      response = item['candidates'][-1]
      samples.append({
          'persona':original_persona,
          'history':history,
          'response':response
      })
  return samples
  
def bertified(samples):
  bertified_data = []
  for item in samples:
    persona = ' <persona> '.join(item['persona'])
    persona = '<bos> ' + persona
    history = ''
    speakers = [" <speaker1> ", " <speaker2> "]
    speaker = 0
    for hst in item['history'][::-1]:
      history = speakers[speaker] + hst + history
      speaker = 1 - speaker
    response = '<speaker2> ' + item['response'] + ' <eos>'
    bertified_data.append({
          'persona':persona.replace('  ', ' '),
          'history':history.replace('  ', ' '),
          'input': persona.replace('  ', ' ')+' '+history.replace('  ', ' '), 
          'response':response.replace('  ', ' ')
      })
  return bertified_data

def bertified_to_model_food(bertified_data, tokenizer):
    model_food = []
    pbar = tqdm(bertified_data)
    pbar.set_description('Tokenizing Data Sample ...')
    for item in pbar:
        inputs = tokenizer(item['input'], add_special_tokens=True, max_length=encoder_max_length, truncation=True, padding="max_length")
        outputs = tokenizer(item['response'], add_special_tokens=True, max_length=decoder_max_length, truncation=True, padding="max_length")
        _item = {}
        _item["input_ids"] = inputs.input_ids
        _item["attention_mask"] = inputs.attention_mask
        _item["decoder_input_ids"] = outputs.input_ids
        _item["decoder_attention_mask"] = outputs.attention_mask
        _item["labels"] = outputs.input_ids.copy()
        model_food.append(_item)
    return model_food

# %%
class PersonaDataset_v3(Dataset):
  '''
      Convert Data to proper Tensor dataset
  '''
  def __init__(self, samples):
    self.samples = samples
    self.n_samples = len(self.samples)

  def __getitem__(self, index):
    # returns specific item
    return self.samples[index]

  def __len__(self):
    return self.n_samples

# %%
from transformers import BertConfig, EncoderDecoderConfig, EncoderDecoderModel
encoder_decoder_config = EncoderDecoderConfig.from_pretrained('/content/drive/MyDrive/checkpoint-37000')
model = EncoderDecoderModel.from_pretrained('/content/drive/MyDrive/checkpoint-37000', config=encoder_decoder_config)

# %%
# train_dataset = PersonaDataset_v3(list(zip(*map(one_line_tokenizer, tqdm(train)))))
train_dataset = PersonaDataset_v3(train)
valid_dataset = PersonaDataset_v3(valid)
test_dataset = PersonaDataset_v3(test[:10])

# %%
rouge = datasets.load_metric("rouge")
def compute_metrics(pred):
    labels_ids = pred.label_ids
    pred_ids = pred.predictions

    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    labels_ids[labels_ids == -100] = tokenizer.pad_token_id
    label_str = tokenizer.batch_decode(labels_ids, skip_special_tokens=True)

    rouge_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge2"])["rouge2"].mid

    return {
        "rouge2_precision": round(rouge_output.precision, 4),
        "rouge2_recall": round(rouge_output.recall, 4),
        "rouge2_fmeasure": round(rouge_output.fmeasure, 4),
    }
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): s3.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/rouge/rouge.py HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com:443
# DEBUG:urllib3.connectionpool:https://raw.githubusercontent.com:443 "HEAD /huggingface/datasets/1.1.2/metrics/rouge/rouge.py HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com:443
# DEBUG:urllib3.connectionpool:https://raw.githubusercontent.com:443 "HEAD /huggingface/datasets/1.1.2/metrics/rouge/dataset_infos.json HTTP/1.1" 404 0
# DEBUG:filelock:Attempting to acquire lock 139941381424016 on /root/.cache/huggingface/datasets/336a0cbdd138e0d6e1361544ed2c56565192be45b5398cd55ac988d4b3fd1455.a89f1fa0750909f2d149b1ecabc808fb66cb865c94bb8bbb135c55deb50da2d7.py.lock
# INFO:filelock:Lock 139941381424016 acquired on /root/.cache/huggingface/datasets/336a0cbdd138e0d6e1361544ed2c56565192be45b5398cd55ac988d4b3fd1455.a89f1fa0750909f2d149b1ecabc808fb66cb865c94bb8bbb135c55deb50da2d7.py.lock
# DEBUG:filelock:Attempting to release lock 139941381424016 on /root/.cache/huggingface/datasets/336a0cbdd138e0d6e1361544ed2c56565192be45b5398cd55ac988d4b3fd1455.a89f1fa0750909f2d149b1ecabc808fb66cb865c94bb8bbb135c55deb50da2d7.py.lock
# INFO:filelock:Lock 139941381424016 released on /root/.cache/huggingface/datasets/336a0cbdd138e0d6e1361544ed2c56565192be45b5398cd55ac988d4b3fd1455.a89f1fa0750909f2d149b1ecabc808fb66cb865c94bb8bbb135c55deb50da2d7.py.lock

# %%
model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.eos_token_id = tokenizer.sep_token_id
model.config.pad_token_id = tokenizer.pad_token_id
model.config.vocab_size = model.config.encoder.vocab_size

# model.config.max_length = 142
# model.config.min_length = 56
model.config.no_repeat_ngram_size = 3
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
from torch import nn
from transformers.trainer_utils import PredictionOutput
import random 


class CustomSeq2SeqTrainer(Seq2SeqTrainer):
    def evaluate(
        self,
        eval_dataset: Optional[Dataset] = None,
        ignore_keys: Optional[List[str]] = None,
        metric_key_prefix: str = "eval",
        max_length: Optional[int] = 128,
        num_beams: Optional[int] = None,
    ) -> Dict[str, float]:
        return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
    def prediction_step(
        self,
        model: nn.Module,
        inputs: Dict[str, Union[torch.Tensor, Any]],
        prediction_loss_only: bool,
        ignore_keys: Optional[List[str]] = None,
    ) -> Tuple[Optional[float], Optional[torch.Tensor], Optional[torch.Tensor]]:
        # global counter, print_threshold
        (loss, logits, labels) = super().prediction_step(model, inputs, prediction_loss_only, ignore_keys)
        # if counter<print_threshold:
        random_subset = random.sample(range(0, len(inputs['labels'])), 10)
        for item in random_subset:
            persona_history_input = self.tokenizer.batch_decode([inputs['input_ids'][item]])
            real_output = self.tokenizer.batch_decode([inputs['labels'][item]])
            model_output = self.tokenizer.batch_decode([logits[item]])
            print("History & Persona & Input: ", persona_history_input[0].replace("<pad>", ""))
            print("Input: ", real_output[0].replace("<pad>", ""))
            print("Output: ", model_output[0].replace("<pad>", ""))
            # counter+=1
        return loss, logits, labels

# %%
steps = 10
batch_size = 64
training_args = Seq2SeqTrainingArguments(
    output_dir="./models/",
    do_eval=True,
    do_predict =True,

    
    evaluation_strategy="steps",
    save_strategy = 'steps',
    
    eval_steps=steps,
    logging_steps=steps,
    save_steps=steps,
    
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    predict_with_generate=True,
    fp16=True, 
    
    
    save_total_limit = 2,
)

# instantiate trainer
def model_init():
    return model


trainer = CustomSeq2SeqTrainer(
    model_init=model_init,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
#     test_dataset=test_dataset,
    tokenizer=tokenizer,
#     max_length = 128
)

# %%
_, _, _ = trainer.predict(test_dataset)
# Out:
# History & Persona & Input:  [CLS] <bos> i only eat kosher. <persona> i was raised in a single parent household. <persona> i read twenty books a year. <persona> i'm a stunt double as my second job. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie [SEP]
# Input:  [CLS] <speaker2> i rather read, i've read about 20 books this year. <eos> [SEP]
# Output:  [CLS] <speaker2> that's cool, i'm a kid. i love the movie. <eos> [SEP]
# History & Persona & Input:  [CLS] <bos> i was raised in a single parent household. <persona> i read twenty books a year. <persona> i'm a stunt double as my second job. <persona> i only eat kosher. <speaker1> hello what are doing today? [SEP]
# Input:  [CLS] <speaker2> i am good, i just got off work and tired, i have two jobs. <eos> [SEP]
# Output:  [CLS] <speaker2> i'm doing well. how are you? <eos> [SEP]
# History & Persona & Input:  [CLS] <bos> i was raised in a single parent household. <persona> i read twenty books a year. <persona> i'm a stunt double as my second job. <persona> i only eat kosher. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie <speaker2> i rather read, i've read about 20 books this year. <speaker1> wow! i do love a good horror movie. loving this cooler weather <speaker2> but a good movie is always good. <speaker1> yes! my son is in junior high and i just started letting him watch them too <speaker2> i work in the movies as well. <speaker1> neat!! i used to work in the human services field [SEP]
# Input:  [CLS] <speaker2> yes it is neat, i stunt double, it is so much fun and hard work. <eos> [SEP]
# Output:  [CLS] <speaker2> that's cool. do you have any hobbies? <eos> [SEP]
# History & Persona & Input:  [CLS] <bos> my favorite music is country. <persona> i own two vintage mustangs. <persona> i have two dogs. <persona> i like to work on vintage cars. <speaker1> hi! how are you doing tonight? <speaker2> i'm doing great. just relaxing with my two dogs. <speaker1> great. in my spare time i do volunteer work. [SEP]
# Input:  [CLS] <speaker2> that's neat. what kind of volunteer work do you do? <eos> [SEP]
# Output:  [CLS] <speaker2> that's cool. do you have any hobbies? i like cars. <eos> [SEP]
# History & Persona & Input:  [CLS] <bos> i'm a stunt double as my second job. <persona> i only eat kosher. <persona> i was raised in a single parent household. <persona> i read twenty books a year. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie <speaker2> i rather read, i've read about 20 books this year. <speaker1> wow! i do love a good horror movie. loving this cooler weather <speaker2> but a good movie is always good. <speaker1> yes! my son is in junior high and i just started letting him watch them too <speaker2> i work in the movies as well. <speaker1> neat!! i used to work in the human services field <speaker2> yes it is neat, i stunt double, it is so much fun and hard work. <speaker1> yes i bet you can get hurt. my wife works and i stay at home <speaker2> nice, i only have one parent so now i help out my mom. <speaker1> i bet she appreciates that very much. [SEP]
# Input:  [CLS] <speaker2> she raised me right, i am just like her. <eos> [SEP]
# Output:  [CLS] <speaker2> she's a teacher, but i'm not sure i've a dog.
# History & Persona & Input:  [CLS] <bos> i only eat kosher. <persona> i was raised in a single parent household. <persona> i read twenty books a year. <persona> i'm a stunt double as my second job. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie <speaker2> i rather read, i've read about 20 books this year. <speaker1> wow! i do love a good horror movie. loving this cooler weather <speaker2> but a good movie is always good. <speaker1> yes! my son is in junior high and i just started letting him watch them too <speaker2> i work in the movies as well. <speaker1> neat!! i used to work in the human services field <speaker2> yes it is neat, i stunt double, it is so much fun and hard work. <speaker1> yes i bet you can get hurt. my wife works and i stay at home [SEP]
# Input:  [CLS] <speaker2> nice, i only have one parent so now i help out my mom. <eos> [SEP]
# Output:  [CLS] <speaker2> i'm sorry to hear that. do you have kids? <eos> [SEP]
# History & Persona & Input:  [CLS] <bos> i own two vintage mustangs. <persona> i have two dogs. <persona> i like to work on vintage cars. <persona> my favorite music is country. <speaker1> hi! how are you doing tonight? [SEP]
# Input:  [CLS] <speaker2> i'm doing great. just relaxing with my two dogs. <eos> [SEP]
# Output:  [CLS] <speaker2> i'm doing well. how are you? <eos> [SEP]
# History & Persona & Input:  [CLS] <bos> i'm a stunt double as my second job. <persona> i only eat kosher. <persona> i was raised in a single parent household. <persona> i read twenty books a year. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie <speaker2> i rather read, i've read about 20 books this year. <speaker1> wow! i do love a good horror movie. loving this cooler weather [SEP]
# Input:  [CLS] <speaker2> but a good movie is always good. <eos> [SEP]
# Output:  [CLS] <speaker2> i love the cold weather. i'm allergic to them. i love it. <eos>
# History & Persona & Input:  [CLS] <bos> i read twenty books a year. <persona> i'm a stunt double as my second job. <persona> i only eat kosher. <persona> i was raised in a single parent household. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie <speaker2> i rather read, i've read about 20 books this year. <speaker1> wow! i do love a good horror movie. loving this cooler weather <speaker2> but a good movie is always good. <speaker1> yes! my son is in junior high and i just started letting him watch them too [SEP]
# Input:  [CLS] <speaker2> i work in the movies as well. <eos> [SEP]
# Output:  [CLS] <speaker2> that's cool. i'm a teacher, but i don't know.
# History & Persona & Input:  [CLS] <bos> i read twenty books a year. <persona> i'm a stunt double as my second job. <persona> i only eat kosher. <persona> i was raised in a single parent household. <speaker1> hello what are doing today? <speaker2> i am good, i just got off work and tired, i have two jobs. <speaker1> i just got done watching a horror movie <speaker2> i rather read, i've read about 20 books this year. <speaker1> wow! i do love a good horror movie. loving this cooler weather <speaker2> but a good movie is always good. <speaker1> yes! my son is in junior high and i just started letting him watch them too <speaker2> i work in the movies as well. <speaker1> neat!! i used to work in the human services field <speaker2> yes it is neat, i stunt double, it is so much fun and hard work. <speaker1> yes i bet you can get hurt. my wife works and i stay at home <speaker2> nice, i only have one parent so now i help out my mom. <speaker1> i bet she appreciates that very much. <speaker2> she raised me right, i am just like her. <speaker1> my dad was always busy working at home depot [SEP]
# Input:  [CLS] <speaker2> now that i am older home depot is my toy r us. <eos> [SEP]
# Output:  [CLS] <speaker2> i'm sorry to hear that. what do you do? <eos> [SEP]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# DEBUG:filelock:Attempting to acquire lock 139941374854864 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139941374854864 acquired on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# DEBUG:filelock:Attempting to release lock 139941374854864 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139941374854864 released on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# DEBUG:filelock:Attempting to acquire lock 139941380660304 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139941380660304 acquired on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:/usr/local/lib/python3.7/dist-packages/datasets/metric.py:Removing /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow
# DEBUG:filelock:Attempting to release lock 139941380660304 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139941380660304 released on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='21' max='5238' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  21/5238 33:09 < 151:45:07, 0.01 it/s, Epoch 0.01/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge2 Precision</th>
#       <th>Rouge2 Recall</th>
#       <th>Rouge2 Fmeasure</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>8.937200</td>
#       <td>4.626111</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1982.985800</td>
#       <td>9.943000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='306' max='309' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [306/309 31:54 < 00:18, 0.16 it/s]
#     </div>
# History & Persona & Input:  [CLS] <bos> i m retired. <persona> i like cooking healthy meals. <persona> i like to go to the gym and work out. <persona> i like to go out to the bars. <speaker1> _ _ silence _ _ <speaker2> hello, how are you today? <speaker1> i am pretty bored today, being nostalgic. [SEP]
# Input:  [CLS] <speaker2> i hear you! maybe i'll go out to a bar tonight. <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air and air air
# History & Persona & Input:  [CLS] <bos> if i m not drinking, i m thinking, which makes me uncomfortable. <persona> i am constantly drinking. <persona> my family loves me, but keeps their distance. <persona> i blame myself for all of my problems. <speaker1> hey there, how do you do? <speaker2> i am okay but i'll be better once i get another drink <speaker1> what do you like to drink? [SEP]
# Input:  [CLS] <speaker2> i love margaritas on the rocks. but any liquor will do the trick <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air and air air
# History & Persona & Input:  [CLS] <bos> i love watching old movies. <persona> i hope to visit quebec, canada someday. <persona> my wife works as a diesel mechanic. <persona> i'm a yoga instructor. <speaker1> hello, what are you up to today? [SEP]
# Input:  [CLS] <speaker2> watching a classic movie the wizard of oz <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / air air cold cold - air
# History & Persona & Input:  [CLS] <bos> i like to draw. <persona> i'm one of four siblings. <persona> my mother is a teacher. <persona> my favorite color is blue. <persona> i live in an apartment. <speaker1> hi how are you today <speaker2> good... how are you doing tonight? <speaker1> i'm good do you work <speaker2> yes... but i really love drawing... do you work? <speaker1> i drive my big truck around [SEP]
# Input:  [CLS] <speaker2> that sounds like a lot of fun what color is your truck? <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air ( force air
# History & Persona & Input:  [CLS] <bos> i learned piano at age 6. <persona> i am a fan of system of a down. <persona> i am trying to play in a local band. <persona> i own 9 guitars. <persona> i'm a vegan. <speaker1> _ _ silence _ _ <speaker2> hi! how are you? what music do you like? <speaker1> i'm god, i like all kinds of music. [SEP]
# Input:  [CLS] <speaker2> i do gigs with my local band. you should come listen! <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air and air air
# History & Persona & Input:  [CLS] <bos> my favorite band is the beastie boys. <persona> i'm a painter. <persona> i want to be a museum curator. <persona> i love coffee with cream. <speaker1> hi how are you today <speaker2> i'm doing well. how about you? <speaker1> i am doing ok got a headache from work. <speaker2> oh wow. what kind of work do you do? <speaker1> i do taxes for companies as an accountant <speaker2> very nice. maybe if you drink some coffee it might help the headache <speaker1> thanks for the advice. what do you do for a living <speaker2> i'm a secretary but also a painter <speaker1> those are great jobs. what kind of things do you paint <speaker2> i like to paint picture of nature. <speaker1> oh you are very talented. have you ever seen a leprechaun <speaker2> yes i have seen pictures of ones <speaker1> i think they're very real. do you have any pets i've a dog [SEP]
# Input:  [CLS] <speaker2> no pets. do you listen to music? <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air and air air
# History & Persona & Input:  [CLS] <bos> i m always happy when the summer ends. <persona> sometimes i wish my computer would work faster. <persona> i like standing in the rain. <persona> rita hayworth is the woman of my dreams. <speaker1> hey, what brings you to the archery range today? <speaker2> i just like to stand in the rain. <speaker1> new class for me. love it! i do not like sports but am good at this <speaker2> i'm just so happy summer is finally over. <speaker1> i work in an office without much time to get out. i enjoyed the summer <speaker2> an office. do you work with computers? <speaker1> i do. i wish i had more time to practice but work is busy <speaker2> i wish they would work faster. sometimes it takes a minute for something to load <speaker1> i agree. if they were faster i could practice and keep improving! <speaker2> do you know the sexy rita hayworth? <speaker1> no i don't, who is that? [SEP]
# Input:  [CLS] <speaker2> only the woman i dream of nightly. <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air ( force air
# History & Persona & Input:  [CLS] <bos> i wish i didn t have to work. <persona> i wish i made more money. <persona> i've a strange obsession with pens. <persona> i enjoy writing for long periods of time. <speaker1> hi how are you tonight? <speaker2> are you a male or a female? can you type faster? <speaker1> i am a female. maybe. <speaker2> i would like to make more money. you? <speaker1> yes, i'd like to make more money. <speaker2> i like to write alot. you ever write erotica? <speaker1> no, i sell paper products. <speaker2> do you work for dunder mifflin? <speaker1> i wish. do you like cheese? i hate it. <speaker2> i like cheese. it would be better if you liked it. <speaker1> i love to cook, what about you? [SEP]
# Input:  [CLS] <speaker2> i would rather you cook for me. <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air ( force air
# History & Persona & Input:  [CLS] <bos> i graduated college in 2016. <persona> i enjoys kayaking in my free time. <persona> i teach kindergarten. <persona> my class has 26 kids. <persona> i teach at a large school. <speaker1> hey, i'm kate. who is there? <speaker2> lindsay here, proud kindergarten teacher <speaker1> i work at a library myself. i like to read! <speaker2> the school i teach at is rather large <speaker1> that's cool. where is it at? <speaker2> its in memphis, tn. my classroom has 26 students, its a lot of 5 6 year olds.. <speaker1> wow cool. is tn hot? i'm not a fan of hot weather. <speaker2> it is humid. whenever i get free time, i like to get out and enjoy kayaking. <speaker1> kayaking sounds fun. especially if you travel. i wish i did. [SEP]
# Input:  [CLS] <speaker2> i wish you the best in life, whatever struggles you have will get better. <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air ( force air
# History & Persona & Input:  [CLS] <bos> i love hanging out with my friends. <persona> my mom is a palm reader in new orleans. <persona> i sometimes spend too much money at the casino. <persona> i once met a man i still believe was a vampire. <persona> my favorite food is shrimp. <speaker1> _ _ silence _ _ <speaker2> hey! whats shakin and bakin? <speaker1> nothing much. relaxing and listening to some chainsmokers! how are you? <speaker2> oh great band. just hanging out. have a few friends over. <speaker1> nice way to spend the weekend. do you have any hobbies? <speaker2> i go to the casino often. i always end up gambling way too much. <speaker1> no risk, no reward! i prefer sports. tennis is my poison! <speaker2> i need to get into that. i just eat a lot. mainly shrimp <speaker1> i love seafood. i travel to the caribbean a lot and have the best food. <speaker2> me too! i prefer my seafood from new orleans. that's where my fam is from <speaker1> do you see them a lot? <speaker2> yes.. mom is a lot of fun. she actually does palm readings. <speaker1> wow! i wish i saw my dad more. he has an offshore oil job [SEP]
# Input:  [CLS] <speaker2> i am sorry. that must be really tough <eos> [SEP]
# Output:  [CLS] ) ( ( air air ) air air air - air air / / air air ( force air
# DEBUG:filelock:Attempting to acquire lock 139683292404176 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683292404176 acquired on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# DEBUG:filelock:Attempting to release lock 139683292404176 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683292404176 released on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# DEBUG:filelock:Attempting to acquire lock 139683414276944 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683414276944 acquired on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:/usr/local/lib/python3.7/dist-packages/datasets/metric.py:Removing /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow
# DEBUG:filelock:Attempting to release lock 139683414276944 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683414276944 released on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='31' max='5238' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  31/5238 1:06:23 < 198:39:59, 0.01 it/s, Epoch 0.02/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge2 Precision</th>
#       <th>Rouge2 Recall</th>
#       <th>Rouge2 Fmeasure</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>8.937200</td>
#       <td>4.626111</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1982.985800</td>
#       <td>9.943000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.554100</td>
#       <td>1.402011</td>
#       <td>0.000400</td>
#       <td>0.000400</td>
#       <td>0.000400</td>
#       <td>1989.761000</td>
#       <td>9.909000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='92' max='309' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 92/309 09:31 < 22:42, 0.16 it/s]
#     </div>
# DEBUG:filelock:Attempting to acquire lock 139683412507472 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683412507472 acquired on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# DEBUG:filelock:Attempting to release lock 139683412507472 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683412507472 released on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# DEBUG:filelock:Attempting to acquire lock 139683406860112 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683406860112 acquired on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:/usr/local/lib/python3.7/dist-packages/datasets/metric.py:Removing /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow
# DEBUG:filelock:Attempting to release lock 139683406860112 on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# INFO:filelock:Lock 139683406860112 released on /root/.cache/huggingface/metrics/rouge/default/default_experiment-1-0.arrow.lock
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-3435b262f1ae> in <module>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, **kwargs)
#    1170                     self.control = self.callback_handler.on_step_end(self.args, self.state, self.control)
#    1171
# -> 1172                     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch)
#    1173
#    1174                 if self.control.should_epoch_stop or self.control.should_training_stop:
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch)
#    1263         metrics = None
#    1264         if self.control.should_evaluate:
# -> 1265             metrics = self.evaluate()
#    1266             self._report_to_hp_search(trial, epoch, metrics)
#    1267
#
# <ipython-input-33-65441455ebb8> in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix, max_length, num_beams)
#      13         num_beams: Optional[int] = None,
#      14     ) -> Dict[str, float]:
# ---> 15         return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
#      16     def prediction_step(
#      17         self,
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer_seq2seq.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix, max_length, num_beams)
#      72         self._max_length = max_length
#      73         self._num_beams = num_beams
# ---> 74         return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
#      75
#      76     def predict(
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    1762             prediction_loss_only=True if self.compute_metrics is None else None,
#    1763             ignore_keys=ignore_keys,
# -> 1764             metric_key_prefix=metric_key_prefix,
#    1765         )
#    1766
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in prediction_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    1893
#    1894         for step, inputs in enumerate(dataloader):
# -> 1895             loss, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    1896             if loss is not None:
#    1897                 losses = loss.repeat(batch_size)
#
# <ipython-input-33-65441455ebb8> in prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#      22     ) -> Tuple[Optional[float], Optional[torch.Tensor], Optional[torch.Tensor]]:
#      23         global counter, print_threshold
# ---> 24         (loss, logits, labels) = super().prediction_step(model, inputs, prediction_loss_only, ignore_keys)
#      25         if counter<print_threshold:
#      26           random_subset = random.sample(range(0, len(inputs['labels'])), 10)
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer_seq2seq.py in prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#     165             inputs["input_ids"],
#     166             attention_mask=inputs["attention_mask"],
# --> 167             **gen_kwargs,
#     168         )
#     169         # in case the batch is shorter than max length, the output should be padded
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py in generate(self, input_ids, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, **model_kwargs)
#    1064                 output_scores=output_scores,
#    1065                 return_dict_in_generate=return_dict_in_generate,
# -> 1066                 **model_kwargs,
#    1067             )
#    1068
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py in beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, **model_kwargs)
#    1746             next_token_scores = F.log_softmax(next_token_logits, dim=-1)  # (batch_size * num_beams, vocab_size)
#    1747
# -> 1748             next_token_scores = logits_processor(input_ids, next_token_scores)
#    1749             next_token_scores = next_token_scores + beam_scores[:, None].expand_as(next_token_scores)
#    1750
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_logits_process.py in __call__(self, input_ids, scores, **kwargs)
#      91                 scores = processor(input_ids, scores, **kwargs)
#      92             else:
# ---> 93                 scores = processor(input_ids, scores)
#      94         return scores
#      95
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_logits_process.py in __call__(self, input_ids, scores)
#     296
#     297         for i, banned_tokens in enumerate(banned_batch_tokens):
# --> 298             scores[i, banned_tokens] = -float("inf")
#     299
#     300         return scores
#
# KeyboardInterrupt:

# %%
# from ray import tune
# from ray.tune.suggest.hyperopt import HyperOptSearch
# from ray.tune.schedulers import AsyncHyperBandScheduler

trainer.hyperparameter_search(
    direction="maximize", 
    backend="ray", 
    n_trials=4, # number of trials
)
# Out:
# == Status ==
# Memory usage on this node: 11.0/31.3 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 1.0/12 CPUs, 1.0/2 GPUs, 0.0/15.6 GiB heap, 0.0/7.8 GiB objects (0.0/1.0 accelerator_type:GTX)
# Result logdir: /home/textmining/ray_results/_objective_2021-04-23_16-10-57
# Number of trials: 4/4 (3 PENDING, 1 RUNNING)
# +------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------+
# | Trial name             | status   | loc   |   learning_rate |   num_train_epochs |   per_device_train_batch_size |     seed |
# |------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------|
# | _objective_c4b35_00000 | RUNNING  |       |     5.61152e-06 |                  5 |                            64 |  8.15396 |
# | _objective_c4b35_00001 | PENDING  |       |     1.56207e-05 |                  2 |                            16 |  7.08379 |
# | _objective_c4b35_00002 | PENDING  |       |     8.28892e-06 |                  5 |                            16 | 24.4435  |
# | _objective_c4b35_00003 | PENDING  |       |     1.09943e-06 |                  2 |                             8 | 29.158   |
# +------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------+
#
#
# == Status ==
# Memory usage on this node: 17.5/31.3 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/12 CPUs, 2.0/2 GPUs, 0.0/15.6 GiB heap, 0.0/7.8 GiB objects (0.0/1.0 accelerator_type:GTX)
# Result logdir: /home/textmining/ray_results/_objective_2021-04-23_16-10-57
# Number of trials: 4/4 (2 PENDING, 2 RUNNING)
# +------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------+
# | Trial name             | status   | loc   |   learning_rate |   num_train_epochs |   per_device_train_batch_size |     seed |
# |------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------|
# | _objective_c4b35_00000 | RUNNING  |       |     5.61152e-06 |                  5 |                            64 |  8.15396 |
# | _objective_c4b35_00001 | RUNNING  |       |     1.56207e-05 |                  2 |                            16 |  7.08379 |
# | _objective_c4b35_00002 | PENDING  |       |     8.28892e-06 |                  5 |                            16 | 24.4435  |
# | _objective_c4b35_00003 | PENDING  |       |     1.09943e-06 |                  2 |                             8 | 29.158   |
# +------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------+
#
#
# == Status ==
# Memory usage on this node: 22.7/31.3 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/12 CPUs, 2.0/2 GPUs, 0.0/15.6 GiB heap, 0.0/7.8 GiB objects (0.0/1.0 accelerator_type:GTX)
# Result logdir: /home/textmining/ray_results/_objective_2021-04-23_16-10-57
# Number of trials: 4/4 (2 PENDING, 2 RUNNING)
# +------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------+
# | Trial name             | status   | loc   |   learning_rate |   num_train_epochs |   per_device_train_batch_size |     seed |
# |------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------|
# | _objective_c4b35_00000 | RUNNING  |       |     5.61152e-06 |                  5 |                            64 |  8.15396 |
# | _objective_c4b35_00001 | RUNNING  |       |     1.56207e-05 |                  2 |                            16 |  7.08379 |
# | _objective_c4b35_00002 | PENDING  |       |     8.28892e-06 |                  5 |                            16 | 24.4435  |
# | _objective_c4b35_00003 | PENDING  |       |     1.09943e-06 |                  2 |                             8 | 29.158   |
# +------------------------+----------+-------+-----------------+--------------------+-------------------------------+----------+
#
#
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) /home/textmining/anaconda3/envs/chatbot/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# (pid=17964)   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) /home/textmining/anaconda3/envs/chatbot/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# (pid=18007)   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# ...
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# 2021-04-23 17:00:15,347	WARNING tune.py:507 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# (pid=17964) <IPython.core.display.HTML object>
# (pid=18007) <IPython.core.display.HTML object>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c51a33e097e8> in <module>
#       6     direction="maximize",
#       7     backend="ray",
# ----> 8     n_trials=4, # number of trials
#       9 )
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/transformers/trainer.py in hyperparameter_search(self, hp_space, compute_objective, n_trials, direction, backend, hp_name, **kwargs)
#    1380
#    1381         run_hp_search = run_hp_search_optuna if backend == HPSearchBackend.OPTUNA else run_hp_search_ray
# -> 1382         best_run = run_hp_search(self, n_trials, direction, **kwargs)
#    1383
#    1384         self.hp_search_backend = None
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/transformers/integrations.py in run_hp_search_ray(trainer, n_trials, direction, **kwargs)
#     235         config=trainer.hp_space(None),
#     236         num_samples=n_trials,
# --> 237         **kwargs,
#     238     )
#     239     best_trial = analysis.get_best_trial(metric="objective", mode=direction[:3])
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, loggers, ray_auto_init, run_errored_only, global_checkpoint_period, with_server, upload_dir, sync_to_cloud, sync_to_driver, sync_on_checkpoint, _remote)
#     518     tune_start = time.time()
#     519     while not runner.is_finished() and not state[signal.SIGINT]:
# --> 520         runner.step()
#     521         if has_verbosity(Verbosity.V1_EXPERIMENT):
#     522             _report_progress(runner, progress_reporter)
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/ray/tune/trial_runner.py in step(self)
#     523                 if self.trial_executor.in_staging_grace_period():
#     524                     timeout = 0.1
# --> 525                 self._process_events(timeout=timeout)  # blocking
#     526             else:
#     527                 self.trial_executor.on_no_available_trials(self)
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/ray/tune/trial_runner.py in _process_events(self, timeout)
#     636             #  fetch_result functionality so that we don't timeout on fetch.
#     637             trial = self.trial_executor.get_next_available_trial(
# --> 638                 timeout=timeout)  # blocking
#     639             if not trial:
#     640                 return
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self, timeout)
#     656         # See https://github.com/ray-project/ray/issues/4211 for details.
#     657         start = time.time()
# --> 658         ready, _ = ray.wait(shuffled_results, timeout=timeout)
#     659         if not ready:
#     660             return None
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#      60         if client_mode_should_convert():
#      61             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 62         return func(*args, **kwargs)
#      63
#      64     return wrapper
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/ray/worker.py in wait(object_refs, num_returns, timeout, fetch_local)
#    1589             timeout_milliseconds,
#    1590             worker.current_task_id,
# -> 1591             fetch_local,
#    1592         )
#    1593         return ready_ids, remaining_ids
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:
