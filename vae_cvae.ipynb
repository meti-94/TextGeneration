# %% [markdown]
# <a href="https://colab.research.google.com/github/meti-94/TextGeneration/blob/main/vae_cvae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/fangleai/TransformerCVAE.git
# Out:
# Cloning into 'TransformerCVAE'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 39 (delta 8), reused 30 (delta 8), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
# !pip install transformers==2.5.1
# !pip install tensorboardX
# !git clone https://github.com/NVIDIA/apex
# %cd /content/apex
# !python setup.py install
# !pip install unidecode
# !pip install nltk
# !pip install rake_nltk
# !pip install bert_serving
# !pip install bert_serving.client
# Out:
# ...
#      |████████████████████████████████| 501kB 24.7MB/s
# ...
#      |████████████████████████████████| 1.2MB 45.8MB/s
# ...
#      |████████████████████████████████| 5.6MB 50.8MB/s
# ...
#      |████████████████████████████████| 901kB 47.5MB/s
# ...
#      |████████████████████████████████| 133kB 55.4MB/s
# ...
#      |████████████████████████████████| 81kB 11.9MB/s
# ...
#      |████████████████████████████████| 7.5MB 39.8MB/s
# ...
# ERROR: botocore 1.20.72 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#      |████████████████████████████████| 122kB 27.6MB/s
# ...
# Cloning into 'apex'...
# remote: Enumerating objects: 8038, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 8038 (delta 58), reused 68 (delta 29), pack-reused 7913
# Receiving objects: 100% (8038/8038), 14.10 MiB | 27.82 MiB/s, done.
# Resolving deltas: 100% (5459/5459), done.
# /content/apex
#
#
# torch.__version__  = 1.8.1+cu101
#
#
# ...

# %%
# !pip install rouge

# %%
# %cd /content
# !wget https://www.dropbox.com/s/24pa44w7u7wvtma/plots.zip?dl=0
# !unzip plots.zip\?dl\=0
# !mkdir /content/TransformerCVAE/data/wikiPlots

# !cp plots /content/TransformerCVAE/data/wikiPlots/plots_paragraph
# !cp titles /content/TransformerCVAE/data/wikiPlots/titles
# Out:
# /content
# --2021-05-13 19:48:15--  https://www.dropbox.com/s/24pa44w7u7wvtma/plots.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/24pa44w7u7wvtma/plots.zip [following]
# --2021-05-13 19:48:15--  https://www.dropbox.com/s/raw/24pa44w7u7wvtma/plots.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucfcfa55289670356fc7360100c0.dl.dropboxusercontent.com/cd/0/inline/BOblr0cyciqR_DwGhzfHkltYT-nt0KS-roRwFftHUltRKSR_xf949-1zOchYosECLnwvBuSNQFaZzW4UwhNS-n7euT8EfcnkvI2r6TM6LgDAGtAXlw1wCbqX6Jtxlyywc1ULD1RdRV2qwuBDJxOaB73w/file# [following]
# ...

# %%
# %cd /content/TransformerCVAE
# !python train.py
# Out:
# /content/TransformerCVAE
# 2021-05-13 19:48:33.035450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# There are  1  available GPUs!
# Using GPU devices 0
# Current single GPU: 0
# Loading models...
# Downloading: 100% 1.04M/1.04M [00:00<00:00, 31.6MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 16.5MB/s]
# Downloading: 100% 665/665 [00:00<00:00, 809kB/s]
# Downloading: 100% 548M/548M [00:09<00:00, 54.9MB/s]
# gpt2_params: 124439808
# VAE_params: 169921536
# Done.
# Setup data...
# Batch schedule [(1, 1024)]
# Loading wikiplot dataset...
# Done.
# Train dataset size 101642
# Val dataset size 5647
# Test dataset size 5647
# Done.
# Wrapping models and optimizers...
# Selected optimization level O0:  Pure FP32 training.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O0
# cast_model_type        : torch.float32
# patch_torch_functions  : False
# ...
